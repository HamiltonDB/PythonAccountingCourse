# %% [markdown]
# # Introduction
# This assignment will be a little different from the others. For the others the problems were pretty simple
# and didn't require much code.
#
# This assignment is intended to be more difficult. It will cover these topics:
# - Files (reading them and writing them)
# - Classes (the basics)
# - String Splitting
# - Globals
#
# Feel free to use multiple functions. Splitting up your code into multiple functions can help
# you work on one problem at a time and make it easier to understand where you might be making mistakes.
#
# If you wish to also test your code yourself you can just make another cell in the middle and run the functions yourself to see what they do.
#
# # To start
# Before you run your code, you should start by running the top cell (the one below this one) to make sure the test file gets generated with contacts. You will also want to run the cell below that which defines the Contact class. You will not be editing this class but using it to do the assignment. This will be what you will be reading in for your code and what you will be working off.

# %%
# Create the test contacts file - RUN THIS FIRST!
def create_test_file():
    """Create a sample contacts file for testing."""
    contacts = [
        "John Doe,202-456-1234,john.doe@example.com",
        "Jane Smith,415-287-5678,jane.smith@example.com",
        "Bob Johnson,312-749-9012,bob.johnson@example.com",
        "Alice Brown,713-624-3456,alice.brown@example.com",
        "David Wilson,305-892-7890,david.wilson@example.com",
        "Emily Davis,404-341-2345,emily.davis@example.com",
        "Michael Taylor,206-773-6789,michael.taylor@example.com",
        "Sarah Miller,617-208-0123,sarah.miller@example.com",
        "James Anderson,702-493-4567,james.anderson@example.com",
        "Jennifer Thomas,214-678-8901,jennifer.thomas@example.com",
        "Robert Martinez,619-234-2345,robert.martinez@example.com",
        "Lisa Robinson,212-905-6789,lisa.robinson@example.com",
        "William Clark,303-321-0123,william.clark@example.com",
        "Patricia Rodriguez,808-631-4567,patricia.rodriguez@example.com",
        "Richard Lewis,216-781-8901,richard.lewis@example.com",
        "Elizabeth Walker,714-523-2345,elizabeth.walker@example.com",
        "Charles Hall,615-889-6789,charles.hall@example.com",
        "Barbara Young,503-421-0123,barbara.young@example.com",
        "Joseph Allen,901-567-4567,joseph.allen@example.com",
        "Margaret Hernandez,609-324-8901,margaret.hernandez@example.com"
    ]
    
    with open("contacts.txt", "w") as f:
        for contact in contacts:
            f.write(contact + "\n")
    
    print(f"Created 'contacts.txt' with {len(contacts)} sample contacts")

# Create the test file
create_test_file()
# Out:
# Created 'contacts.txt' with 20 sample contacts

# %%
# DO NOT EDIT - RUN THIS BEFORE YOU DO YOUR CODE
class Contact:
    """A class representing a contact with name, phone number, and email."""
    
    def __init__(self, name, phone, email=""):
        """Initialize a Contact object."""
        self.name = name
        self.phone = phone
        self.email = email
    
    def __repr__(self):
        """Return string representation of contact."""
        return f"Contact('{self.name}', '{self.phone}', '{self.email}')"
    
    def __eq__(self, other):
        """Compare two contacts for equality."""
        if not isinstance(other, Contact):
            return False
        return (self.name == other.name and 
                self.phone == other.phone and 
                self.email == other.email)
    
    def update_phone(self, new_phone):
        """Update the contact's phone number."""
        self.phone = new_phone
        return self
    
    def update_email(self, new_email):
        """Update the contact's email address."""
        self.email = new_email
        return self
    
    def to_dict(self):
        """Convert contact to dictionary."""
        return {
            'name': self.name,
            'phone': self.phone,
            'email': self.email
        }

# %%
# Where you work

# Implement these functions
def import_contacts(filename):
    """
    Import contacts from a CSV file.
    
    The file format has a header row and then data rows:
    name,phone,email
    John Doe,202-456-1234,john.doe@example.com
    
    Args:
        filename: The name of the CSV file to load
        
    Returns:
        A list of Contact objects
    """
    
    # YOUR CODE HERE
    pass


def update_contact_phone(contacts, name, new_phone):
    """
    Update a contact's phone number.
    
    Find a contact by name (case-sensitive) and update their phone number.
    
    Args:
        contacts: A list of Contact objects
        name: The exact name of the contact to update
        new_phone: New phone number
    
    Returns:
        The updated list of contacts
    """
    
    # YOUR CODE HERE
    pass


def update_contact_email(contacts, name, new_email):
    """
    Update a contact's email address.
    
    Find a contact by name (case-sensitive) and update their email address.
    
    Args:
        contacts: A list of Contact objects
        name: The exact name of the contact to update
        new_email: New email address
    
    Returns:
        The updated list of contacts
    """
    
    # YOUR CODE HERE
    pass


def export_contacts(contacts, filename):
    """
    Export a list of contacts to a CSV file.
    
    The output file should have a header row and then data rows:
    name,phone,email
    John Doe,202-456-1234,john.doe@example.com
    
    Args:
        contacts: A list of Contact objects
        filename: The name of the CSV file to save to
    """
    
    # YOUR CODE HERE
    pass

# %%
# Import contacts from file
contacts = import_contacts("contacts.csv")

# Update John's phone number
update_contact_phone(contacts, "John Doe", "555-123-4567")

# Update Jane's email
update_contact_email(contacts, "Jane Smith", "jane.updated@example.com")

# Export the updated contacts
export_contacts(contacts, "updated_contacts.csv")
